# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Pravimo praznu sliku sa belom pozadinom</h2>

# %%
prazna_slika = array_created = np.full((500, 500, 3), 255, dtype = np.uint8)
plt.imshow(prazna_slika)

# %% [markdown]
# <h2>Crtamo krugove po slici</h2>

# %%
# slika_sa_krugom = cv2.circle(slika, koordinate, radijus, boja, debljina_linije)
slika_sa_oblicima = cv2.circle(prazna_slika, (200,200), 30, (0,0,255), 2)
cv2.circle(slika_sa_oblicima, (100,100), 50, (255,0,0), -1)
cv2.circle(slika_sa_oblicima, (300,250), 70, (38,170,30), -1)
cv2.circle(slika_sa_oblicima, (300,250), 40, (240,170,30), -1)
plt.imshow(slika_sa_oblicima)

# %% [markdown]
# <h2>Crtamo linije po slici</h2>

# %%
l = cv2.line(slika_sa_oblicima, (100, 400), (300, 450), (255, 0, 0), 5)
plt.imshow(slika_sa_oblicima)

# %% [markdown]
# <h2>Crtamo poligon po slici</h2>

# %%
tacke = np.array([[20,250],[120,350],[70,20],[50,10]], np.int32)
tacke = tacke.reshape((-1,1,2))
cv2.polylines(slika_sa_oblicima,[tacke],True,(0,0,255))

plt.imshow(slika_sa_oblicima)

# %% [markdown]
# <h2>Crtamo pravougaonike po slici</h2>

# %%
cv2.rectangle(slika_sa_oblicima,(384,20),(480,128),(0,255,0),3)
cv2.rectangle(slika_sa_oblicima,(340,370),(480,450),(10,20,255),-3)
plt.imshow(slika_sa_oblicima)
